# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("MyProject").config("spark.driver.memory","2g").getOrCreate()
print("Spark Session Successfully Started Locally")
# Out:
# Spark Session Successfully Started Locally
